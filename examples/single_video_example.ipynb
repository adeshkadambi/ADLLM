# %%
import sys
sys.path.append('..')

# %%
import os

video_dir = "/media/adeshkadambi/WD_BLACK/PhD/adl_recognition/test_folder/"
video_name = "SCI02-2--9.MP4"

video_path = os.path.join(video_dir, video_name); video_path
# Out:
# '/media/adeshkadambi/WD_BLACK/PhD/adl_recognition/test_folder/SCI02-2--9.MP4'

# %%
import video_utils as vu

sampled_frames, sampled_indices, total_frames = vu.extract_frames(
    path=os.path.join(video_dir, video_name),
    sampling_method=vu.SamplingStrategy.UNIFORM,
    num_frames=4,
    save_frames=True,
)
print(f"Extracted {len(sampled_frames)} frames")
print(f"Sampled indices: {sampled_indices}")
print(f"Total frames: {total_frames}")
# Out:
# Extracted 4 frames
# Sampled indices: [0, 199, 399, 599]
# Total frames: 600

# %%
import matplotlib.pyplot as plt
from inference import ADLClassifier

clf = ADLClassifier()
response = clf.predict(sampled_frames, sampled_indices, total_frames)

plt.imshow(response['Image_Grid'])
plt.axis("off")
plt.show()

response
# Out:
# 100%|██████████| 4/4 [00:32<00:00,  8.21s/it]
# Frame analysis completed.
# Frame synthesis completed.
# ADL classification completed.
# {'ADL': 'Feeding',
#  'Reasoning': 'The individual is actively engaged in eating breakfast, using both hands to manipulate food and utensils. The sequence of object interactions with hands follows a predictable pattern: fork is used to bring food to mouth (Frames 199 and 599), knife is held in left hand (Frame 399), and cup of coffee/tea is grasped by right hand (Frame 599). This consistent use of utensils and the presence of food on the plate indicate that the primary activity being performed is feeding.',
#  'Intermediate_Steps': {'Environment_Analysis': 'The environment is a kitchen setting with a wooden table and chairs, glass top, and colorful placemat underneath the plate. Key objects include a white plate containing breakfast food (poached eggs, bacon, toast, fruit), cup of coffee or tea, fork, knife, small bowl of fresh fruit, and blue tablet or e-reader.',
#   'Action_Sequence': 'The sequence of actions visible across frames includes: right hand holds fork, bringing food to mouth (Frame 199); both hands are positioned on either side of the plate; right hand grasps cup of coffee/tea; left hand holds fork, poised above plate; person takes a bite of food from the plate.',
#   'OT_Discussion': 'Four occupational therapists discussed the classification. Three agreed that feeding was the primary activity being performed, while one suggested meal preparation due to the presence of cooking utensils and ingredients on the table. However, the majority consensus was that feeding was the correct classification because the individual is actively eating.',
#   'Critical_Evaluation': 'Three occupational therapists critically evaluated the consensus classification. One therapist questioned whether the individual was actually preparing a meal or just eating, but the majority agreed that the evidence supported feeding as the primary activity. Another therapist suggested that the presence of a tablet on the table indicated leisure activities, but this did not change the overall classification.',
#   'Final_Verification': "The final verification confirmed that the correct classification was indeed Feeding. The individual's actions and interactions with objects clearly demonstrated eating as the primary activity being performed."},
#  'Image_Grid': <PIL.Image.Image image mode=RGB size=1120x630>}
